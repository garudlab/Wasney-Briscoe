# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob

import bz2

import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc('text', usetex=True)
plt.rc('text', usetex=True)
plt.rc('text.latex', preamble=r'\usepackage{amsmath}') 
import seaborn as sns
import numpy as np
from matplotlib.lines import Line2D
from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition,
                                                  mark_inset)
import scipy.stats
import figure_utils as fu
from return_gene_descriptions import return_gene_descriptions

from numba import njit 

import matplotlib.pyplot as plt
import pickle
import pandas as pd
import config
import numpy
import random as rand

from random import randint,sample
from math import log

import matplotlib.cm as cm
plasma_cmap = cm.get_cmap('plasma')
import matplotlib.colors as mcolors

import sys
import os 
from scipy.spatial.distance import pdist,squareform

import matplotlib.gridspec as gridspec

from matplotlib.lines import Line2D
from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition,
                                                  mark_inset)
from matplotlib.colors import ListedColormap

hap_cmap = ListedColormap(['grey', 'red', 'black', 'black','blue'], 'indexed')

from strain_phasing_functions import *
# Out:
# /u/home/m/michaelw/.conda/envs/python_env/lib/python3.6/site-packages/ipykernel_launcher.py:16: MatplotlibDeprecationWarning:
# The mpl_toolkits.axes_grid module was deprecated in Matplotlib 2.1 and will be removed two minor releases later. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist, which provide the same functionality instead.
#   app.launch_new_instance()

# %% [markdown]
# ### Loading species list

# %%
oligo_species_list_path = "%s%s" %(config.project_directory, "metadata/oligo_species.txt")
with open(oligo_species_list_path, "r") as file:
    oligo_species_list = [line.strip() for line in file]

# %% [markdown]
# # Loop through species

# %%
label_x_position = [0.01,0.51]
label_y_position = [1*(1/6), 2*(1/6), 2*(1/6), 4*(1/6), 5*(1/6), 6*(1/6)]

### LEGEND

cmap_clus = get_cmap(5,name="Set3")

legend_elements = [
    Line2D([0], [0], color = cmap_clus(1), lw = 7, label='Strain 1'),
    Line2D([0], [0], color = cmap_clus(0), lw = 7, label='Strain 2'),
    Line2D([0], [0], color = cmap_clus(2), lw = 7, label='Strain 3'),
    
]


oligo_species_list.sort()
#oligo_species_list = [species for species in oligo_species_list if species != "Alistipes_shahii_62199"]
# oligo_species_list = oligo_species_list[:4]

num_rows = 6
num_cols = 2

# num_rows = 2
# num_cols = 2

fig, axes = plt.subplots(nrows = num_rows, ncols = num_cols, figsize=(30, 20))

#axes = axes.flatten()

for species_index,ax in enumerate(axes.reshape(-1)):
    if species_index != len(axes.reshape(-1)) - 1:
        plot_strains(oligo_species_list[species_index], fig, ax)
    else: 
        ax.axis('off')

#fig stuff
fig.legend(handles = legend_elements, prop={"size":30}, bbox_to_anchor=(0.8, 0.1, 0.0, 0.0))
fig.text(label_x_position[0], 1, 'A', fontsize=30, fontweight='bold', fontname='Helvetica')
fig.text(label_x_position[1], 1, 'B', fontsize=30, fontweight='bold', fontname='Helvetica')
fig.text(label_x_position[0], 0.83, 'C', fontsize=30, fontweight='bold', fontname='Helvetica')
fig.text(label_x_position[1], 0.83, 'D', fontsize=30, fontweight='bold', fontname='Helvetica')
fig.text(label_x_position[0], 0.66, 'E', fontsize=30, fontweight='bold', fontname='Helvetica')
fig.text(label_x_position[1], 0.66, 'F', fontsize=30, fontweight='bold', fontname='Helvetica')
fig.text(label_x_position[0], 0.5, 'G', fontsize=30, fontweight='bold', fontname='Helvetica')
fig.text(label_x_position[1], 0.5, 'H', fontsize=30, fontweight='bold', fontname='Helvetica')
fig.text(label_x_position[0], 0.33, 'I', fontsize=30, fontweight='bold', fontname='Helvetica')
fig.text(label_x_position[1], 0.33, 'J', fontsize=30, fontweight='bold', fontname='Helvetica')
fig.text(label_x_position[0], 0.167, 'k', fontsize=30, fontweight='bold', fontname='Helvetica')
fig.text(0.5, 0.0, 'Sample', ha='center', size = 30, fontname='Helvetica')
fig.text(0, 0.5, 'Strain frequency', va='center', rotation='vertical', size = 30, fontname='Helvetica')

fig.subplots_adjust()
fig.tight_layout(rect = (0.025,0.02,1,1)) #

# Show the overall plot
plt.show()
# Out:
# Cluster directory already exists.
# Cluster directory already exists.
# Cluster directory already exists.
# Cluster directory already exists.
# Cluster directory already exists.
# Cluster directory already exists.
# Cluster directory already exists.
# Cluster directory already exists.
# Cluster directory already exists.
# Cluster directory already exists.
# Cluster directory already exists.

# %%
figure_directory = "%s%s" % (config.figure_directory, "figures/")
figure_path = "%sfigure_4.png" % (figure_directory)
fig.savefig(figure_path, facecolor='white', transparent=False, dpi=300,bbox_inches='tight')

# %%
figure_path
# Out:
# '/u/project/ngarud/michaelw/Diversity-Along-Gut/HumanizedMouse/figures/figures/figure_4.png'
